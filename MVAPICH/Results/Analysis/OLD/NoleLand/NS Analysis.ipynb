# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math
import PyGnuplot as gp

sns.set()
sns.set_style("whitegrid")



data = pd.read_excel('Allgather-MVAPICH-NoleLand.xlsx', sheet_name='Summary')

MessageSizes = list(data['Unnamed: 0'][4:24])

# %%
import matplotlib.font_manager as font_manager
font_prop = font_manager.FontProperties(size=20, family='Times')
def my_plot(subplot, x, y, labels):    
    colors = ['blue', 'red', 'green', 'black', 'orange', 'teal', 'purple', 'navy']
    
    for i in range(len(labels)):
        subplot.plot(x, y[i], '-x', color=colors[i], label=labels[i] , markersize=10, linewidth=2)
    
    
    subplot.tick_params(labelsize=14)
    subplot.set_xticks(x[-4:])
    
    
    subplot.set_xlabel('Message Size (B)', fontproperties=font_prop)
    subplot.set_ylabel('Latency (us)', fontproperties=font_prop)
    
    subplot.legend(fontsize=15)
    
def compute_overheads(base, results):
    overheads=[]
    for r in results:
        overheads.append([100*(i-j)/j for i,j in zip(r, base)])
    return overheads

def plot_overheads(x, overheads, labels):
    colors = ['orange', 'red', 'green', 'blue', 'black', 'pink']
    barwidth = 0.13
    fig =plt.subplots(figsize=(20, 8))
    
    for i in range(len(overheads)):
        x_br = [j + i*barwidth for j in range(len(x))]
        plt.bar(x_br, overheads[i], width=barwidth, label=labels[i], color=colors[i])
        
    plt.xlabel('Message Size (B)', fontproperties=font_prop)
    plt.ylabel('Latency Overhead %', fontproperties=font_prop)
    
    plt.xticks([r + barwidth for r in range(len(x))], [str(s) for s in x])
    plt.tick_params(labelsize=15)
    plt.legend(fontsize=15)
    plt.show()
    

def categorize(lists, s_t, m_t):
    s_list, m_list, l_list= [], [], []
    for l in lists:
        s_list.append(l[3:s_t])
        m_list.append(l[s_t:m_t])
        l_list.append(l[m_t:])
    return s_list, m_list, l_list

# %% [markdown]
# # 4 Nodes - 32 ranks

# %% [markdown]
# ## Unencrypted

# %%
Unenc_Default_4_32 = list(data['Unnamed: 1'][4:24])
Unenc_Default_SendPlus_4_32 = list(data['Unnamed: 2'][4:24])
Unenc_NB_4_32 = list(data['Unnamed: 3'][4:24])
Unenc_RingNB_4_32 = list(data['Unnamed: 4'][4:24])
Unenc_ML_4_32 = list(data['Unnamed: 5'][4:24])
Unenc_MLRD_4_32 = list(data['Unnamed: 6'][4:24])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4_32[:13], Unenc_Default_SendPlus_4_32[:13], Unenc_NB_4_32[:13], Unenc_RingNB_4_32[:13], Unenc_ML_4_32[:13], Unenc_MLRD_4_32[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4_32[13:], Unenc_Default_SendPlus_4_32[13:], Unenc_NB_4_32[13:], Unenc_RingNB_4_32[13:], Unenc_ML_4_32[13:], Unenc_MLRD_4_32[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()

# %%
overheads_4_32 = compute_overheads(Unenc_Default_4_32, [Unenc_Default_SendPlus_4_32, Unenc_NB_4_32, Unenc_RingNB_4_32, Unenc_ML_4_32, Unenc_MLRD_4_32])

first_med_msg_idx = 9
first_large_msgs_idx = 13
s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads_4_32, first_med_msg_idx, first_large_msgs_idx)


plot_overheads(MessageSizes[3:first_med_msg_idx], s_m_overheads, ['Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_med_msg_idx:first_large_msgs_idx], m_m_overheads, ['Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# ## Naive

# %%
Naive_Default_4_32 = list(data['Unnamed: 6'][4:24])
Naive_Default_SendPlus_4_32 = list(data['Unnamed: 7'][4:24])
Naive_NB_4_32 = list(data['Unnamed: 8'][4:24])
Naive_RingNB_4_32 = list(data['Unnamed: 9'][4:24])
Naive_ML_4_32 = list(data['Unnamed: 10'][4:24])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Naive_Default_4_32[:13], Naive_Default_SendPlus_4_32[:13], Naive_NB_4_32[:13], Naive_RingNB_4_32[:13], Naive_ML_4_32[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])
my_plot(h2, MessageSizes[13:], [Naive_Default_4_32[13:], Naive_Default_SendPlus_4_32[13:], Naive_NB_4_32[13:], Naive_RingNB_4_32[13:], Naive_ML_4_32[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive", fontproperties=font_prop)

plt.show()

# %%
overheads_Naiuve_4_32 = compute_overheads(Unenc_Default_4_32, [Naive_Default_4_32, Naive_Default_SendPlus_4_32, Naive_RingNB_4_32, Naive_ML_4_32])


first_med_msg_idx = 9
first_large_msgs_idx = 13
s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads_Naiuve_4_32, first_med_msg_idx, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_med_msg_idx], s_m_overheads, ['Default', 'Send+', 'RingNB', 'MultiLeader'])

plot_overheads(MessageSizes[first_med_msg_idx:first_large_msgs_idx], m_m_overheads, ['Default', 'Send+', 'RingNB', 'MultiLeader'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default', 'Send+', 'RingNB', 'MultiLeader'])

# %% [markdown]
# ## Naive+

# %%
NaivePlus_Default_4_32 = list(data['Unnamed: 13'][4:24])
NaivePlus_Default_SendPlus_4_32 = list(data['Unnamed: 14'][4:24])
NaivePlus_NB_4_32 = list(data['Unnamed: 15'][4:24])
NaivePlus_RingNB_4_32 = list(data['Unnamed: 16'][4:24])
NaivePlus_ML_4_32 = list(data['Unnamed: 17'][4:24])
NaivePlus_MLRD_4_32 = list(data['Unnamed: 18'][4:24])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [NaivePlus_Default_4_32[:13], NaivePlus_Default_SendPlus_4_32[:13], NaivePlus_NB_4_32[:13], NaivePlus_RingNB_4_32[:13], NaivePlus_ML_4_32[:13], NaivePlus_MLRD_4_32[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[13:], [NaivePlus_Default_4_32[13:], NaivePlus_Default_SendPlus_4_32[13:], NaivePlus_NB_4_32[13:], NaivePlus_RingNB_4_32[13:], NaivePlus_ML_4_32[13:], NaivePlus_MLRD_4_32[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive +", fontproperties=font_prop)

plt.show()

# %%
overheads_NaivePlus_4_32 = compute_overheads(Unenc_Default_4_32, [NaivePlus_Default_4_32, NaivePlus_Default_SendPlus_4_32, NaivePlus_NB_4_32, NaivePlus_ML_4_32, NaivePlus_MLRD_4_32])

first_med_msg_idx = 9
first_large_msgs_idx = 13
s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads_NaivePlus_4_32, first_med_msg_idx, first_large_msgs_idx)


plot_overheads(MessageSizes[3:first_med_msg_idx], s_m_overheads, ['Default', 'Send+', 'NB', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_med_msg_idx:first_large_msgs_idx], m_m_overheads, ['Default', 'Send+', 'NB', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default', 'Send+', 'NB', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# # 4 Nodes, 64 ranks

# %% [markdown]
# ## Unencrypted

# %%
Unenc_Default_4_64 = list(data['Unnamed: 1'][32:52])
Unenc_Default_SendPlus_4_64 = list(data['Unnamed: 2'][32:52])
Unenc_NB_4_64 = list(data['Unnamed: 3'][32:52])
Unenc_RingNB_4_64 = list(data['Unnamed: 4'][32:52])
Unenc_ML_4_64 = list(data['Unnamed: 5'][32:52])
Unenc_MLRD_4_64 = list(data['Unnamed: 6'][32:52])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4_64[:13], Unenc_Default_SendPlus_4_64[:13], Unenc_NB_4_64[:13], Unenc_RingNB_4_64[:13], Unenc_ML_4_64[:13], Unenc_MLRD_4_64[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4_64[13:], Unenc_Default_SendPlus_4_64[13:], Unenc_NB_4_64[13:], Unenc_RingNB_4_64[13:], Unenc_ML_4_64[13:], Unenc_MLRD_4_64[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()

# %%
overheads_4_64 = compute_overheads(Unenc_Default_4_64, [Unenc_Default_SendPlus_4_64, Unenc_NB_4_64, Unenc_ML_4_64, Unenc_MLRD_4_64])

first_med_msg_idx = 9
first_large_msgs_idx = 13
s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads_4_64, first_med_msg_idx, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_med_msg_idx], s_m_overheads, ['Send+', 'NB', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_med_msg_idx:first_large_msgs_idx], m_m_overheads, ['Send+', 'NB', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Send+', 'NB', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# # Naive

# %%
Naive_Default_4_64 = list(data['Unnamed: 6'][32:52])
Naive_Default_SendPlus_4_64 = list(data['Unnamed: 7'][32:52])
Naive_NB_4_64 = list(data['Unnamed: 8'][32:52])
Naive_RingNB_4_64 = list(data['Unnamed: 9'][32:52])
Naive_ML_4_64 = list(data['Unnamed: 10'][32:52])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Naive_Default_4_64[:13], Naive_Default_SendPlus_4_64[:13], Naive_NB_4_64[:13], Naive_RingNB_4_64[:13], Naive_ML_4_64[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])
my_plot(h2, MessageSizes[13:], [Naive_Default_4_64[13:], Naive_Default_SendPlus_4_64[13:], Naive_NB_4_64[13:], Naive_RingNB_4_64[13:], Naive_ML_4_64[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive", fontproperties=font_prop)

plt.show()

# %%
overheads_Naiuve_4_64 = compute_overheads(Unenc_Default_4_64, [Naive_Default_4_64, Naive_Default_SendPlus_4_64, Naive_RingNB_4_64, Naive_ML_4_64])


first_med_msg_idx = 9
first_large_msgs_idx = 13
s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads_Naiuve_4_64, first_med_msg_idx, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_med_msg_idx], s_m_overheads, ['Default', 'Send+', 'RingNB', 'MultiLeader'])

plot_overheads(MessageSizes[first_med_msg_idx:first_large_msgs_idx], m_m_overheads, ['Default', 'Send+', 'RingNB', 'MultiLeader'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default', 'Send+', 'RingNB', 'MultiLeader'])

# %% [markdown]
# ## Naive+

# %%
NaivePlus_Default_4_64 = list(data['Unnamed: 13'][32:52])
NaivePlus_Default_SendPlus_4_64 = list(data['Unnamed: 14'][32:52])
NaivePlus_NB_4_64 = list(data['Unnamed: 15'][32:52])
NaivePlus_RingNB_4_64 = list(data['Unnamed: 16'][32:52])
NaivePlus_ML_4_64 = list(data['Unnamed: 17'][32:52])
NaivePlus_MLRD_4_64 = list(data['Unnamed: 18'][32:52])


f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [NaivePlus_Default_4_64[:13], NaivePlus_Default_SendPlus_4_64[:13], NaivePlus_NB_4_64[:13], NaivePlus_RingNB_4_64[:13], NaivePlus_ML_4_64[:13], NaivePlus_MLRD_4_64[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[13:], [NaivePlus_Default_4_64[13:], NaivePlus_Default_SendPlus_4_64[13:], NaivePlus_NB_4_64[13:], NaivePlus_RingNB_4_64[13:], NaivePlus_ML_4_64[13:], NaivePlus_MLRD_4_64[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive +", fontproperties=font_prop)

plt.show()

# %%
overheads_NaivePlus_4_64 = compute_overheads(Unenc_Default_4_64, [NaivePlus_Default_4_64, NaivePlus_Default_SendPlus_4_64, NaivePlus_ML_4_64, NaivePlus_MLRD_4_64])

first_med_msg_idx = 9
first_large_msgs_idx = 13
s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads_NaivePlus_4_64, first_med_msg_idx, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_med_msg_idx], s_m_overheads, ['Default', 'Send+', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_med_msg_idx:first_large_msgs_idx], m_m_overheads, ['Default', 'Send+', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default', 'Send+', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# # 8 Nodes, 32 ranks

# %% [markdown]
# ## Unencrypted

# %%
Unenc_Default_8_32 = list(data['Unnamed: 1'][60:80])
Unenc_Default_SendPlus_8_32 = list(data['Unnamed: 2'][60:80])
Unenc_NB_8_32 = list(data['Unnamed: 3'][60:80])
Unenc_RingNB_8_32 = list(data['Unnamed: 4'][60:80])
Unenc_ML_8_32 = list(data['Unnamed: 5'][60:80])
Unenc_MLRD_8_32 = list(data['Unnamed: 6'][60:80])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_8_32[:13], Unenc_Default_SendPlus_8_32[:13], Unenc_NB_8_32[:13], Unenc_RingNB_8_32[:13], Unenc_ML_8_32[:13], Unenc_MLRD_8_32[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_8_32[13:], Unenc_Default_SendPlus_8_32[13:], Unenc_NB_8_32[13:], Unenc_RingNB_8_32[13:], Unenc_ML_8_32[13:], Unenc_MLRD_8_32[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()

# %%
overheads_8_32 = compute_overheads(Unenc_Default_8_32, [Unenc_Default_SendPlus_8_32, Unenc_ML_8_32, Unenc_MLRD_8_32])

first_med_msg_idx = 9
first_large_msgs_idx = 13
s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads_8_32, first_med_msg_idx, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_med_msg_idx], s_m_overheads, ['Send+', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_med_msg_idx:first_large_msgs_idx], m_m_overheads, ['Send+', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Send+', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# ## Naive

# %%
Naive_Default_8_32 = list(data['Unnamed: 6'][60:80])
Naive_Default_SendPlus_8_32 = list(data['Unnamed: 7'][60:80])
Naive_NB_8_32 = list(data['Unnamed: 8'][60:80])
Naive_RingNB_8_32 = list(data['Unnamed: 9'][60:80])
Naive_ML_8_32 = list(data['Unnamed: 10'][60:80])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Naive_Default_8_32[:13], Naive_Default_SendPlus_8_32[:13], Naive_NB_8_32[:13], Naive_RingNB_8_32[:13], Naive_ML_8_32[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])
my_plot(h2, MessageSizes[13:], [Naive_Default_8_32[13:], Naive_Default_SendPlus_8_32[13:], Naive_NB_8_32[13:], Naive_RingNB_8_32[13:], Naive_ML_8_32[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive", fontproperties=font_prop)

plt.show()

# %%
overheads_Naiuve_8_32 = compute_overheads(Unenc_Default_8_32, [Naive_Default_8_32, Naive_Default_SendPlus_8_32, Naive_RingNB_8_32, Naive_ML_8_32])


first_med_msg_idx = 9
first_large_msgs_idx = 13
s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads_Naiuve_8_32, first_med_msg_idx, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_med_msg_idx], s_m_overheads, ['Default', 'Send+', 'RingNB', 'MultiLeader'])

plot_overheads(MessageSizes[first_med_msg_idx:first_large_msgs_idx], m_m_overheads, ['Default', 'Send+', 'RingNB', 'MultiLeader'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default', 'Send+', 'RingNB', 'MultiLeader'])

# %% [markdown]
# ## Naive+

# %%
NaivePlus_Default_8_32 = list(data['Unnamed: 13'][60:80])
NaivePlus_Default_SendPlus_8_32 = list(data['Unnamed: 14'][60:80])
NaivePlus_NB_8_32 = list(data['Unnamed: 15'][60:80])
NaivePlus_RingNB_8_32 = list(data['Unnamed: 16'][60:80])
NaivePlus_ML_8_32 = list(data['Unnamed: 17'][60:80])
NaivePlus_MLRD_8_32 = list(data['Unnamed: 18'][60:80])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [NaivePlus_Default_8_32[:13], NaivePlus_Default_SendPlus_8_32[:13], NaivePlus_NB_8_32[:13], NaivePlus_RingNB_8_32[:13], NaivePlus_ML_8_32[:13], NaivePlus_MLRD_8_32[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[13:], [NaivePlus_Default_8_32[13:], NaivePlus_Default_SendPlus_8_32[13:], NaivePlus_NB_8_32[13:], NaivePlus_RingNB_8_32[13:], NaivePlus_ML_8_32[13:], NaivePlus_MLRD_8_32[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive +", fontproperties=font_prop)

plt.show()

# %%
overheads_NaivePlus_8_32 = compute_overheads(Unenc_Default_8_32, [NaivePlus_Default_8_32, NaivePlus_Default_SendPlus_8_32, NaivePlus_ML_8_32, NaivePlus_MLRD_8_32])

first_med_msg_idx = 9
first_large_msgs_idx = 13
s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads_NaivePlus_8_32, first_med_msg_idx, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_med_msg_idx], s_m_overheads, ['Default', 'Send+', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_med_msg_idx:first_large_msgs_idx], m_m_overheads, ['Default', 'Send+', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default', 'Send+', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# # 8 Nodes, 64 ranks

# %% [markdown]
# ## Unencrypted

# %%
Unenc_Default_8_64 = list(data['Unnamed: 1'][88:108])
Unenc_Default_SendPlus_8_64 = list(data['Unnamed: 2'][88:108])
Unenc_NB_8_64 = list(data['Unnamed: 3'][88:108])
Unenc_RingNB_8_64 = list(data['Unnamed: 4'][88:108])
Unenc_ML_8_64 = list(data['Unnamed: 5'][88:108])
Unenc_MLRD_8_64 = list(data['Unnamed: 6'][88:108])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_8_64[:13], Unenc_Default_SendPlus_8_64[:13], Unenc_NB_8_64[:13], Unenc_RingNB_8_64[:13], Unenc_ML_8_64[:13], Unenc_MLRD_8_64[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_8_64[13:], Unenc_Default_SendPlus_8_64[13:], Unenc_NB_8_64[13:], Unenc_RingNB_8_64[13:], Unenc_ML_8_64[13:], Unenc_MLRD_8_64[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()

# %%
overheads_8_64 = compute_overheads(Unenc_Default_8_64, [Unenc_Default_SendPlus_8_64, Unenc_ML_8_64, Unenc_MLRD_8_64])

first_med_msg_idx = 9
first_large_msgs_idx = 13
s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads_8_64, first_med_msg_idx, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_med_msg_idx], s_m_overheads, ['Send+', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_med_msg_idx:first_large_msgs_idx], m_m_overheads, ['Send+', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Send+', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# ## Naive

# %%
Naive_Default_8_64 = list(data['Unnamed: 6'][88:108])
Naive_Default_SendPlus_8_64 = list(data['Unnamed: 7'][88:108])
Naive_NB_8_64 = list(data['Unnamed: 8'][88:108])
Naive_RingNB_8_64 = list(data['Unnamed: 9'][88:108])
Naive_ML_8_64 = list(data['Unnamed: 10'][88:108])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Naive_Default_8_64[:13], Naive_Default_SendPlus_8_64[:13], Naive_NB_8_64[:13], Naive_RingNB_8_64[:13], Naive_ML_8_64[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])
my_plot(h2, MessageSizes[13:], [Naive_Default_8_64[13:], Naive_Default_SendPlus_8_64[13:], Naive_NB_8_64[13:], Naive_RingNB_8_64[13:], Naive_ML_8_64[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive", fontproperties=font_prop)

plt.show()

# %%
overheads_Naiuve_8_64 = compute_overheads(Unenc_Default_8_64, [Naive_Default_8_64, Naive_Default_SendPlus_8_64, Naive_RingNB_8_64, Naive_ML_8_64])


first_med_msg_idx = 9
first_large_msgs_idx = 13
s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads_Naiuve_8_64, first_med_msg_idx, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_med_msg_idx], s_m_overheads, ['Default', 'Send+', 'RingNB', 'MultiLeader'])

plot_overheads(MessageSizes[first_med_msg_idx:first_large_msgs_idx], m_m_overheads, ['Default', 'Send+', 'RingNB', 'MultiLeader'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default', 'Send+', 'RingNB', 'MultiLeader'])

# %% [markdown]
# ## Naive+

# %%
NaivePlus_Default_8_64 = list(data['Unnamed: 13'][88:108])
NaivePlus_Default_SendPlus_8_64 = list(data['Unnamed: 14'][88:108])
NaivePlus_NB_8_64 = list(data['Unnamed: 15'][88:108])
NaivePlus_RingNB_8_64 = list(data['Unnamed: 16'][88:108])
NaivePlus_ML_8_64 = list(data['Unnamed: 17'][88:108])
NaivePlus_MLRD_8_64 = list(data['Unnamed: 18'][88:108])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [NaivePlus_Default_8_64[:13], NaivePlus_Default_SendPlus_8_64[:13], NaivePlus_NB_8_64[:13], NaivePlus_RingNB_8_64[:13], NaivePlus_ML_8_64[:13], NaivePlus_MLRD_8_64[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[13:], [NaivePlus_Default_8_64[13:], NaivePlus_Default_SendPlus_8_64[13:], NaivePlus_NB_8_64[13:], NaivePlus_RingNB_8_64[13:], NaivePlus_ML_8_64[13:], NaivePlus_MLRD_8_64[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive +", fontproperties=font_prop)

plt.show()

# %%
overheads_NaivePlus_8_64 = compute_overheads(Unenc_Default_8_64, [NaivePlus_Default_8_64, NaivePlus_Default_SendPlus_8_64, NaivePlus_ML_8_64, NaivePlus_MLRD_8_64])

first_med_msg_idx = 9
first_large_msgs_idx = 13
s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads_NaivePlus_8_64, first_med_msg_idx, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_med_msg_idx], s_m_overheads, ['Default', 'Send+', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_med_msg_idx:first_large_msgs_idx], m_m_overheads, ['Default', 'Send+', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default', 'Send+', 'ML-Ring', 'ML-RD'])
