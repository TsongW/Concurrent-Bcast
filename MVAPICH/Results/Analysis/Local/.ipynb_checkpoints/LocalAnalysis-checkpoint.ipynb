# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math
import PyGnuplot as gp

sns.set()
sns.set_style("whitegrid")



#inv_data = pd.read_excel('Inv-Allgather-MVAPICH.xlsx', sheet_name='Summary')
ns_data = pd.read_excel('NS-Allgather-MVAPICH.xlsx', sheet_name='Summary')

MessageSizes = list(ns_data['Unnamed: 0'][3:25])


print(MessageSizes)
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152]

# %%
import matplotlib.font_manager as font_manager
font_prop = font_manager.FontProperties(size=20, family='Times')
def my_plot(subplot, x, y, labels):    
    colors = ['blue', 'red', 'green', 'black', 'orange', 'teal', 'purple', 'navy']
    
    for i in range(len(labels)):
        subplot.plot(x, y[i], '-x', color=colors[i], label=labels[i] , markersize=10, linewidth=2)
    
    
    subplot.tick_params(labelsize=14)
    subplot.set_xticks(x[-4:])
    
    
    subplot.set_xlabel('Message Size (B)', fontproperties=font_prop)
    subplot.set_ylabel('Latency (us)', fontproperties=font_prop)
    
    subplot.legend(fontsize=15)
    
def compute_overheads(base, results):
    overheads=[]
    for r in results:
        overheads.append([100*(i-j)/j for i,j in zip(r, base)])
    return overheads

def plot_overheads(x, overheads, labels):
    colors = ['orange', 'red', 'green', 'blue', 'black', 'pink']
    barwidth = 0.13
    fig =plt.subplots(figsize=(20, 8))
    
    for i in range(len(overheads)):
        x_br = [j + i*barwidth for j in range(len(x))]
        plt.bar(x_br, overheads[i], width=barwidth, label=labels[i], color=colors[i])
        
    plt.xlabel('Message Size (B)', fontproperties=font_prop)
    plt.ylabel('Latency Overhead %', fontproperties=font_prop)
    
    plt.xticks([r + barwidth for r in range(len(x))], [str(s) for s in x])
    plt.tick_params(labelsize=15)
    plt.legend(fontsize=15)
    plt.show()
    

def categorize(lists, l_t):
    s_list, l_list= [], []
    for l in lists:
        s_list.append(l[:l_t])
        l_list.append(l[l_t:])
    return s_list, l_list

# %% [markdown]
# # Inv - 4 Nodes - 32 ranks - Block

# %% [markdown]
# ## Unencrypted

# %%
INV_Unenc_Default_4_32 = list(inv_data['Unnamed: 1'][3:17])
INV_Unenc_Default_SendPlus_4_32 = list(inv_data['Unnamed: 2'][3:17])
INV_Unenc_NB_4_32 = list(inv_data['Unnamed: 3'][3:17])
INV_Unenc_RingNB_4_32 = list(inv_data['Unnamed: 4'][3:17])
INV_Unenc_ML_4_32 = list(inv_data['Unnamed: 5'][3:17])
INV_Unenc_MLRD_4_32 = list(inv_data['Unnamed: 6'][3:17])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [INV_Unenc_Default_4_32[:6], INV_Unenc_Default_SendPlus_4_32[:6], INV_Unenc_NB_4_32[:6], INV_Unenc_RingNB_4_32[:6], INV_Unenc_ML_4_32[:6], INV_Unenc_MLRD_4_32[:6]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [INV_Unenc_Default_4_32[6:], INV_Unenc_Default_SendPlus_4_32[6:], INV_Unenc_NB_4_32[6:], INV_Unenc_RingNB_4_32[6:], INV_Unenc_ML_4_32[6:], INV_Unenc_MLRD_4_32[6:]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()

# %%
overheads_4_32 = compute_overheads(INV_Unenc_Default_4_32, [INV_Unenc_Default_SendPlus_4_32, INV_Unenc_NB_4_32, INV_Unenc_RingNB_4_32, INV_Unenc_ML_4_32, INV_Unenc_MLRD_4_32])


first_large_msgs_idx = 6
s_m_overheads, l_m_overheads = categorize(overheads_4_32, first_large_msgs_idx)


# plot_overheads(MessageSizes[:first_large_msgs_idx], s_m_overheads, ['Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

# plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads[:1]+l_m_overheads[2:], ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# %%
INV_NaivePlus_Default_4_32 = list(inv_data['Unnamed: 11'][3:17])
INV_NaivePlus_Default_SendPlus_4_32 = list(inv_data['Unnamed: 12'][3:17])
INV_NaivePlus_NB_4_32 = list(inv_data['Unnamed: 13'][3:17])
INV_NaivePlus_RingNB_4_32 = list(inv_data['Unnamed: 14'][3:17])
INV_NaivePlus_ML_4_32 = list(inv_data['Unnamed: 15'][3:17])
INV_NaivePlus_MLRD_4_32 = list(inv_data['Unnamed: 16'][3:17])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [INV_NaivePlus_Default_4_32[:6], INV_NaivePlus_Default_SendPlus_4_32[:6], INV_NaivePlus_NB_4_32[:6], INV_NaivePlus_RingNB_4_32[:6], INV_NaivePlus_ML_4_32[:6], INV_NaivePlus_MLRD_4_32[:6]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [INV_NaivePlus_Default_4_32[6:], INV_NaivePlus_Default_SendPlus_4_32[6:], INV_NaivePlus_NB_4_32[6:], INV_NaivePlus_RingNB_4_32[6:], INV_NaivePlus_ML_4_32[6:], INV_NaivePlus_MLRD_4_32[6:]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("NaivePlus", fontproperties=font_prop)

plt.show()

# %% [markdown]
# # Inv - 4 Nodes - 32 ranks - Cyclic

# %%
INV_Unenc_C_Default_4_32 = list(inv_data['Unnamed: 1'][24:38])
INV_Unenc_C_Default_SendPlus_4_32 = list(inv_data['Unnamed: 2'][24:38])
INV_Unenc_C_NB_4_32 = list(inv_data['Unnamed: 3'][24:38])
INV_Unenc_C_RingNB_4_32 = list(inv_data['Unnamed: 4'][24:38])
INV_Unenc_C_ML_4_32 = list(inv_data['Unnamed: 5'][24:38])
INV_Unenc_C_MLRD_4_32 = list(inv_data['Unnamed: 6'][24:38])


f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [INV_Unenc_C_Default_4_32[:6], INV_Unenc_C_Default_SendPlus_4_32[:6], INV_Unenc_C_NB_4_32[:6], INV_Unenc_C_RingNB_4_32[:6], INV_Unenc_C_ML_4_32[:6], INV_Unenc_C_MLRD_4_32[:6]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [INV_Unenc_C_Default_4_32[6:], INV_Unenc_C_Default_SendPlus_4_32[6:], INV_Unenc_C_NB_4_32[6:], INV_Unenc_C_RingNB_4_32[6:], INV_Unenc_C_ML_4_32[6:], INV_Unenc_C_MLRD_4_32[6:]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()







# f = plt.figure(figsize=(16,6))
# h1 = f.add_subplot(121)
# h2 = f.add_subplot(122)

# my_plot(h1, MessageSizes[:6], [INV_Unenc_C_NB_4_32[:6], INV_Unenc_C_RingNB_4_32[:6], INV_Unenc_C_ML_4_32[:6], INV_Unenc_C_MLRD_4_32[:6]], ['NB', 'RingNB', 'ML-Ring', 'ML-RD'])
# my_plot(h2, MessageSizes[6:], [INV_Unenc_C_NB_4_32[6:], INV_Unenc_C_RingNB_4_32[6:], INV_Unenc_C_ML_4_32[6:], INV_Unenc_C_MLRD_4_32[6:]], ['NB', 'RingNB', 'ML-Ring', 'ML-RD'])
# #INV_Unenc_C_Default_4_32[:6], INV_Unenc_C_Default_SendPlus_4_32[:6],
# plt.legend(prop=font_prop)
# plt.tight_layout()
# plt.title("Unencrypted", fontproperties=font_prop)

# plt.show()


inv_unenc_c_overheads_4_32 = compute_overheads(INV_Unenc_Default_4_32, [ INV_Unenc_C_NB_4_32, INV_Unenc_C_RingNB_4_32, INV_Unenc_C_ML_4_32, INV_Unenc_C_MLRD_4_32])


first_large_msgs_idx = 6
s_m_overheads, l_m_overheads = categorize(inv_unenc_c_overheads_4_32, first_large_msgs_idx)


# plot_overheads(MessageSizes[:first_large_msgs_idx], s_m_overheads, ['NB', 'RingNB', 'ML-Ring', 'ML-RD'])

# plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['NB', 'RingNB', 'ML-Ring', 'ML-RD'])

# %%
INV_NaivePlus_C_Default_4_32 = list(inv_data['Unnamed: 11'][24:38])
INV_NaivePlus_C_Default_SendPlus_4_32 = list(inv_data['Unnamed: 12'][24:38])
INV_NaivePlus_C_NB_4_32 = list(inv_data['Unnamed: 13'][24:38])
INV_NaivePlus_C_RingNB_4_32 = list(inv_data['Unnamed: 14'][24:38])
INV_NaivePlus_C_ML_4_32 = list(inv_data['Unnamed: 15'][24:38])
INV_NaivePlus_C_MLRD_4_32 = list(inv_data['Unnamed: 16'][24:38])


f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [INV_NaivePlus_C_Default_4_32[:6], INV_NaivePlus_C_Default_SendPlus_4_32[:6], INV_NaivePlus_C_NB_4_32[:6], INV_NaivePlus_C_RingNB_4_32[:6], INV_NaivePlus_C_ML_4_32[:6], INV_NaivePlus_C_MLRD_4_32[:6]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [INV_NaivePlus_C_Default_4_32[6:], INV_NaivePlus_C_Default_SendPlus_4_32[6:], INV_NaivePlus_C_NB_4_32[6:], INV_NaivePlus_C_RingNB_4_32[6:], INV_NaivePlus_C_ML_4_32[6:], INV_NaivePlus_C_MLRD_4_32[6:]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("NaivePlus", fontproperties=font_prop)

plt.show()

# %% [markdown]
# # Inv - 4 Nodes, 64 ranks - Blocked

# %% [markdown]
# ## Unencrypted

# %%
INV_Unenc_Default_4_64 = list(inv_data['Unnamed: 1'][45:59])
INV_Unenc_Default_SendPlus_4_64 = list(inv_data['Unnamed: 2'][45:59])
INV_Unenc_NB_4_64 = list(inv_data['Unnamed: 3'][45:59])
INV_Unenc_RingNB_4_64 = list(inv_data['Unnamed: 4'][45:59])
INV_Unenc_ML_4_64 = list(inv_data['Unnamed: 5'][45:59])
INV_Unenc_MLRD_4_64 = list(inv_data['Unnamed: 6'][45:59])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [INV_Unenc_Default_4_64[:6], INV_Unenc_Default_SendPlus_4_64[:6], INV_Unenc_RingNB_4_64[:6], INV_Unenc_ML_4_64[:6], INV_Unenc_MLRD_4_64[:6]], ['Default', 'Default Send+', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [INV_Unenc_Default_4_64[6:], INV_Unenc_Default_SendPlus_4_64[6:], INV_Unenc_RingNB_4_64[6:], INV_Unenc_ML_4_64[6:], INV_Unenc_MLRD_4_64[6:]], ['Default', 'Default Send+', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()

# %%
inv_unenc_overheads_4_64 = compute_overheads(INV_Unenc_Default_4_64, [INV_Unenc_Default_SendPlus_4_64, INV_Unenc_RingNB_4_64, INV_Unenc_ML_4_64, INV_Unenc_MLRD_4_64])


first_large_msgs_idx = 6
s_m_overheads, l_m_overheads = categorize(inv_unenc_overheads_4_64, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_large_msgs_idx], s_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# # NS - 4 Nodes, 32 ranks - Blocked

# %%
NS_Unenc_Default_4_32 = list(ns_data['Unnamed: 1'][3:17])
NS_Unenc_Default_SendPlus_4_32 = list(ns_data['Unnamed: 2'][3:17])
NS_Unenc_NB_4_32 = list(ns_data['Unnamed: 3'][3:17])
NS_Unenc_RingNB_4_32 = list(ns_data['Unnamed: 4'][3:17])
NS_Unenc_ML_4_32 = list(ns_data['Unnamed: 5'][3:17])
NS_Unenc_MLRD_4_32 = list(ns_data['Unnamed: 6'][3:17])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_Unenc_Default_4_32[:6], NS_Unenc_Default_SendPlus_4_32[:6], NS_Unenc_NB_4_32[:6], NS_Unenc_RingNB_4_32[:6], NS_Unenc_ML_4_32[:6], NS_Unenc_MLRD_4_32[:6]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_Unenc_Default_4_32[6:], NS_Unenc_Default_SendPlus_4_32[6:], NS_Unenc_NB_4_32[6:], NS_Unenc_RingNB_4_32[6:], NS_Unenc_ML_4_32[6:], NS_Unenc_MLRD_4_32[6:]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()



f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_Unenc_Default_4_32[:6], NS_Unenc_Default_SendPlus_4_32[:6], NS_Unenc_RingNB_4_32[:6], NS_Unenc_ML_4_32[:6], NS_Unenc_MLRD_4_32[:6]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_Unenc_Default_4_32[6:], NS_Unenc_Default_SendPlus_4_32[6:], NS_Unenc_RingNB_4_32[6:], NS_Unenc_ML_4_32[6:], NS_Unenc_MLRD_4_32[6:]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()




ns_unenc_overheads_4_32 = compute_overheads(NS_Unenc_Default_4_32, [NS_Unenc_Default_SendPlus_4_32, NS_Unenc_RingNB_4_32, INV_Unenc_ML_4_32, INV_Unenc_MLRD_4_32])


first_large_msgs_idx = 6
s_m_overheads, l_m_overheads = categorize(ns_unenc_overheads_4_32, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_large_msgs_idx], s_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# # NS - 4 Nodes, 64 ranks - Blocked

# %%
NS_Unenc_Default_4_64 = list(ns_data['Unnamed: 1'][24:38])
NS_Unenc_Default_SendPlus_4_64 = list(ns_data['Unnamed: 2'][24:38])
NS_Unenc_NB_4_64 = list(ns_data['Unnamed: 3'][24:38])
NS_Unenc_RingNB_4_64 = list(ns_data['Unnamed: 4'][24:38])
NS_Unenc_ML_4_64 = list(ns_data['Unnamed: 5'][24:38])
NS_Unenc_MLRD_4_64 = list(ns_data['Unnamed: 6'][24:38])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_Unenc_Default_4_64[:6], NS_Unenc_Default_SendPlus_4_64[:6], NS_Unenc_NB_4_64[:6], NS_Unenc_RingNB_4_64[:6], NS_Unenc_ML_4_64[:6], NS_Unenc_MLRD_4_64[:6]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_Unenc_Default_4_64[6:], NS_Unenc_Default_SendPlus_4_64[6:], NS_Unenc_NB_4_64[6:], NS_Unenc_RingNB_4_64[6:], NS_Unenc_ML_4_64[6:], NS_Unenc_MLRD_4_64[6:]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()



f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_Unenc_Default_4_64[:6], NS_Unenc_Default_SendPlus_4_64[:6], NS_Unenc_RingNB_4_64[:6], NS_Unenc_ML_4_64[:6], NS_Unenc_MLRD_4_64[:6]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_Unenc_Default_4_64[6:], NS_Unenc_Default_SendPlus_4_64[6:], NS_Unenc_RingNB_4_64[6:], NS_Unenc_ML_4_64[6:], NS_Unenc_MLRD_4_64[6:]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()


ns_unenc_overheads_4_64 = compute_overheads(NS_Unenc_Default_4_64, [NS_Unenc_Default_SendPlus_4_64, NS_Unenc_RingNB_4_64, NS_Unenc_ML_4_64, NS_Unenc_MLRD_4_64])


first_large_msgs_idx = 6
s_m_overheads, l_m_overheads = categorize(ns_unenc_overheads_4_64, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_large_msgs_idx], s_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# # NS - 4 Nodes, 64 ranks - Cyclic

# %%
NS_Unenc_C_Default_4_64 = list(ns_data['Unnamed: 1'][45:59])
NS_Unenc_C_Default_SendPlus_4_64 = list(ns_data['Unnamed: 2'][45:59])
NS_Unenc_C_NB_4_64 = list(ns_data['Unnamed: 3'][45:59])
NS_Unenc_C_RingNB_4_64 = list(ns_data['Unnamed: 4'][45:59])
NS_Unenc_C_ML_4_64 = list(ns_data['Unnamed: 5'][45:59])
NS_Unenc_C_MLRD_4_64 = list(ns_data['Unnamed: 6'][45:59])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_Unenc_C_Default_4_64[:6], NS_Unenc_C_Default_SendPlus_4_64[:6], NS_Unenc_C_NB_4_64[:6], NS_Unenc_C_RingNB_4_64[:6], NS_Unenc_C_ML_4_64[:6], NS_Unenc_C_MLRD_4_64[:6]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_Unenc_C_Default_4_64[6:], NS_Unenc_C_Default_SendPlus_4_64[6:], NS_Unenc_C_NB_4_64[6:], NS_Unenc_C_RingNB_4_64[6:], NS_Unenc_C_ML_4_64[6:], NS_Unenc_C_MLRD_4_64[6:]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()



f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_Unenc_C_RingNB_4_64[:6], NS_Unenc_C_ML_4_64[:6], NS_Unenc_C_MLRD_4_64[:6]], ['RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_Unenc_C_RingNB_4_64[6:], NS_Unenc_C_ML_4_64[6:], NS_Unenc_C_MLRD_4_64[6:]], ['RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()


ns_unenc_c_overheads_4_64 = compute_overheads(NS_Unenc_C_Default_4_64, [NS_Unenc_C_Default_SendPlus_4_64, NS_Unenc_C_RingNB_4_64, NS_Unenc_C_ML_4_64, NS_Unenc_C_MLRD_4_64])


first_large_msgs_idx = 6
s_m_overheads, l_m_overheads = categorize(ns_unenc_c_overheads_4_64, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_large_msgs_idx], s_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# # NS - 7 Nodes, 91 ranks - Blocked

# %%
NS_Unenc_Default_7_91 = list(ns_data['Unnamed: 1'][66:80])
NS_Unenc_Default_SendPlus_7_91 = list(ns_data['Unnamed: 2'][66:80])
NS_Unenc_NB_7_91 = list(ns_data['Unnamed: 3'][66:80])
NS_Unenc_RingNB_7_91 = list(ns_data['Unnamed: 4'][66:80])
NS_Unenc_ML_7_91 = list(ns_data['Unnamed: 5'][66:80])
NS_Unenc_MLRD_7_91 = list(ns_data['Unnamed: 6'][66:80])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_Unenc_Default_7_91[:6], NS_Unenc_Default_SendPlus_7_91[:6], NS_Unenc_NB_7_91[:6], NS_Unenc_RingNB_7_91[:6], NS_Unenc_ML_7_91[:6], NS_Unenc_MLRD_7_91[:6]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_Unenc_Default_7_91[6:], NS_Unenc_Default_SendPlus_7_91[6:], NS_Unenc_NB_7_91[6:], NS_Unenc_RingNB_7_91[6:], NS_Unenc_ML_7_91[6:], NS_Unenc_MLRD_7_91[6:]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()



# f = plt.figure(figsize=(16,6))
# h1 = f.add_subplot(121)
# h2 = f.add_subplot(122)

# my_plot(h1, MessageSizes[:6], [NS_Unenc_Default_7_91[:6], NS_Unenc_Default_SendPlus_7_91[:6], NS_Unenc_RingNB_7_91[:6], NS_Unenc_ML_7_91[:6], NS_Unenc_MLRD_7_91[:6]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])
# my_plot(h2, MessageSizes[6:], [NS_Unenc_Default_7_91[6:], NS_Unenc_Default_SendPlus_7_91[6:], NS_Unenc_RingNB_7_91[6:], NS_Unenc_ML_7_91[6:], NS_Unenc_MLRD_7_91[6:]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# plt.legend(prop=font_prop)
# plt.tight_layout()
# plt.title("Unencrypted", fontproperties=font_prop)

# plt.show()


# ns_unenc_overheads_7_91 = compute_overheads(NS_Unenc_Default_7_91, [NS_Unenc_Default_SendPlus_7_91, NS_Unenc_RingNB_7_91, NS_Unenc_ML_7_91, NS_Unenc_MLRD_7_91])


# first_large_msgs_idx = 6
# s_m_overheads, l_m_overheads = categorize(ns_unenc_overheads_7_91, first_large_msgs_idx)


# plot_overheads(MessageSizes[:first_large_msgs_idx], s_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# %%
NS_NaivePlus_Default_7_91 = list(ns_data['Unnamed: 11'][66:80])
NS_NaivePlus_Default_SendPlus_7_91 = list(ns_data['Unnamed: 12'][66:80])
NS_NaivePlus_NB_7_91 = list(ns_data['Unnamed: 13'][66:80])
NS_NaivePlus_RingNB_7_91 = list(ns_data['Unnamed: 14'][66:80])
NS_NaivePlus_ML_7_91 = list(ns_data['Unnamed: 15'][66:80])
NS_NaivePlus_MLRD_7_91 = list(ns_data['Unnamed: 16'][66:80])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_NaivePlus_Default_7_91[:6], NS_NaivePlus_Default_SendPlus_7_91[:6], NS_NaivePlus_NB_7_91[:6], NS_NaivePlus_RingNB_7_91[:6], NS_NaivePlus_ML_7_91[:6], NS_NaivePlus_MLRD_7_91[:6]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_NaivePlus_Default_7_91[6:], NS_NaivePlus_Default_SendPlus_7_91[6:], NS_NaivePlus_NB_7_91[6:], NS_NaivePlus_RingNB_7_91[6:], NS_NaivePlus_ML_7_91[6:], NS_NaivePlus_MLRD_7_91[6:]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("NaivePlus", fontproperties=font_prop)

plt.show()

# %% [markdown]
# # NS - 7 Nodes, 91 ranks - Cyclic

# %%
NS_Unenc_C_Default_7_91 = list(ns_data['Unnamed: 1'][87:101])
NS_Unenc_C_Default_SendPlus_7_91 = list(ns_data['Unnamed: 2'][87:101])
NS_Unenc_C_NB_7_91 = list(ns_data['Unnamed: 3'][87:101])
NS_Unenc_C_RingNB_7_91 = list(ns_data['Unnamed: 4'][87:101])
NS_Unenc_C_ML_7_91 = list(ns_data['Unnamed: 5'][87:101])
NS_Unenc_C_MLRD_7_91 = list(ns_data['Unnamed: 6'][87:101])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_Unenc_C_Default_7_91[:6], NS_Unenc_C_Default_SendPlus_7_91[:6], NS_Unenc_C_NB_7_91[:6], NS_Unenc_C_RingNB_7_91[:6], NS_Unenc_C_ML_7_91[:6], NS_Unenc_C_MLRD_7_91[:6]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_Unenc_C_Default_7_91[6:], NS_Unenc_C_Default_SendPlus_7_91[6:], NS_Unenc_C_NB_7_91[6:], NS_Unenc_C_RingNB_7_91[6:], NS_Unenc_C_ML_7_91[6:], NS_Unenc_C_MLRD_7_91[6:]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()



# f = plt.figure(figsize=(16,6))
# h1 = f.add_subplot(121)
# h2 = f.add_subplot(122)

# my_plot(h1, MessageSizes[:6], [NS_Unenc_C_RingNB_7_91[:6], NS_Unenc_C_ML_7_91[:6], NS_Unenc_C_MLRD_7_91[:6]], ['RingNB', 'ML-Ring', 'ML-RD'])
# my_plot(h2, MessageSizes[6:], [NS_Unenc_C_RingNB_7_91[6:], NS_Unenc_C_ML_7_91[6:], NS_Unenc_C_MLRD_7_91[6:]], ['RingNB', 'ML-Ring', 'ML-RD'])

# plt.legend(prop=font_prop)
# plt.tight_layout()
# plt.title("Unencrypted", fontproperties=font_prop)

# plt.show()


# ns_unenc_c_overheads_7_91 = compute_overheads(NS_Unenc_C_Default_7_91, [NS_Unenc_C_Default_SendPlus_7_91, NS_Unenc_C_RingNB_7_91, NS_Unenc_C_ML_7_91, NS_Unenc_C_MLRD_7_91])


# first_large_msgs_idx = 6
# s_m_overheads, l_m_overheads = categorize(ns_unenc_c_overheads_7_91, first_large_msgs_idx)


# # plot_overheads(MessageSizes[:first_large_msgs_idx], s_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# # plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# %%
NS_NaivePlus_C_Default_7_91 = list(ns_data['Unnamed: 11'][87:101])
NS_NaivePlus_C_Default_SendPlus_7_91 = list(ns_data['Unnamed: 12'][87:101])
NS_NaivePlus_C_NB_7_91 = list(ns_data['Unnamed: 13'][87:101])
NS_NaivePlus_C_RingNB_7_91 = list(ns_data['Unnamed: 14'][87:101])
NS_NaivePlus_C_ML_7_91 = list(ns_data['Unnamed: 15'][87:101])
NS_NaivePlus_C_MLRD_7_91 = list(ns_data['Unnamed: 16'][87:101])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_NaivePlus_C_Default_7_91[:6], NS_NaivePlus_C_Default_SendPlus_7_91[:6], NS_NaivePlus_C_NB_7_91[:6], NS_NaivePlus_C_RingNB_7_91[:6], NS_NaivePlus_C_ML_7_91[:6], NS_NaivePlus_C_MLRD_7_91[:6]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_NaivePlus_C_Default_7_91[6:], NS_NaivePlus_C_Default_SendPlus_7_91[6:], NS_NaivePlus_C_NB_7_91[6:], NS_NaivePlus_C_RingNB_7_91[6:], NS_NaivePlus_C_ML_7_91[6:], NS_NaivePlus_C_MLRD_7_91[6:]], ['Default', 'Default+', 'NB', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("NaivePlus", fontproperties=font_prop)

plt.show()

# %% [markdown]
# # NS - 8 Nodes, 64 ranks - Blocked

# %%
NS_Unenc_Default_8_64 = list(ns_data['Unnamed: 1'][108:122])
NS_Unenc_Default_SendPlus_8_64 = list(ns_data['Unnamed: 2'][108:122])
NS_Unenc_NB_8_64 = list(ns_data['Unnamed: 3'][108:122])
NS_Unenc_RingNB_8_64 = list(ns_data['Unnamed: 4'][108:122])
NS_Unenc_ML_8_64 = list(ns_data['Unnamed: 5'][108:122])
NS_Unenc_MLRD_8_64 = list(ns_data['Unnamed: 6'][108:122])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_Unenc_Default_8_64[:6], NS_Unenc_Default_SendPlus_8_64[:6], NS_Unenc_RingNB_8_64[:6], NS_Unenc_ML_8_64[:6], NS_Unenc_MLRD_8_64[:6]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_Unenc_Default_8_64[6:], NS_Unenc_Default_SendPlus_8_64[6:], NS_Unenc_RingNB_8_64[6:], NS_Unenc_ML_8_64[6:], NS_Unenc_MLRD_8_64[6:]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()



# ns_unenc_overheads_8_64 = compute_overheads(NS_Unenc_Default_8_64, [NS_Unenc_Default_SendPlus_8_64, NS_Unenc_RingNB_8_64, NS_Unenc_ML_8_64, NS_Unenc_MLRD_8_64])


# first_large_msgs_idx = 6
# s_m_overheads, l_m_overheads = categorize(ns_unenc_overheads_8_64, first_large_msgs_idx)


# plot_overheads(MessageSizes[:first_large_msgs_idx], s_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# %%
NS_NaivePlus_Default_8_64 = list(ns_data['Unnamed: 11'][108:122])
NS_NaivePlus_Default_SendPlus_8_64 = list(ns_data['Unnamed: 12'][108:122])
NS_NaivePlus_NB_8_64 = list(ns_data['Unnamed: 13'][108:122])
NS_NaivePlus_RingNB_8_64 = list(ns_data['Unnamed: 14'][108:122])
NS_NaivePlus_ML_8_64 = list(ns_data['Unnamed: 15'][108:122])
NS_NaivePlus_MLRD_8_64 = list(ns_data['Unnamed: 16'][108:122])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_NaivePlus_Default_8_64[:6], NS_NaivePlus_Default_SendPlus_8_64[:6], NS_NaivePlus_RingNB_8_64[:6], NS_NaivePlus_ML_8_64[:6], NS_NaivePlus_MLRD_8_64[:6]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_NaivePlus_Default_8_64[6:], NS_NaivePlus_Default_SendPlus_8_64[6:], NS_NaivePlus_RingNB_8_64[6:], NS_NaivePlus_ML_8_64[6:], NS_NaivePlus_MLRD_8_64[6:]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("NaivePlus", fontproperties=font_prop)

plt.show()



ns_NaivePlus_overheads_8_64 = compute_overheads(NS_NaivePlus_Default_8_64, [NS_NaivePlus_Default_SendPlus_8_64, NS_NaivePlus_RingNB_8_64, NS_NaivePlus_ML_8_64, NS_NaivePlus_MLRD_8_64])


first_large_msgs_idx = 6
s_m_overheads, l_m_overheads = categorize(ns_NaivePlus_overheads_8_64, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_large_msgs_idx], s_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# # NS - 8 Nodes, 64 ranks - Cyclic

# %%
NS_Unenc_C_Default_8_64 = list(ns_data['Unnamed: 1'][129:143])
NS_Unenc_C_Default_SendPlus_8_64 = list(ns_data['Unnamed: 2'][129:143])
NS_Unenc_C_NB_8_64 = list(ns_data['Unnamed: 3'][129:143])
NS_Unenc_C_RingNB_8_64 = list(ns_data['Unnamed: 4'][129:143])
NS_Unenc_C_ML_8_64 = list(ns_data['Unnamed: 5'][129:143])
NS_Unenc_C_MLRD_8_64 = list(ns_data['Unnamed: 6'][129:143])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_Unenc_C_Default_8_64[:6], NS_Unenc_C_Default_SendPlus_8_64[:6], NS_Unenc_C_RingNB_8_64[:6], NS_Unenc_C_ML_8_64[:6], NS_Unenc_C_MLRD_8_64[:6]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_Unenc_C_Default_8_64[6:], NS_Unenc_C_Default_SendPlus_8_64[6:], NS_Unenc_C_RingNB_8_64[6:], NS_Unenc_C_ML_8_64[6:], NS_Unenc_C_MLRD_8_64[6:]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()


ns_unenc_c_overheads_7_91 = compute_overheads(NS_Unenc_C_Default_7_91, [NS_Unenc_C_Default_SendPlus_7_91, NS_Unenc_C_RingNB_7_91, NS_Unenc_C_ML_7_91, NS_Unenc_C_MLRD_7_91])


first_large_msgs_idx = 6
s_m_overheads, l_m_overheads = categorize(ns_unenc_c_overheads_7_91, first_large_msgs_idx)


# plot_overheads(MessageSizes[:first_large_msgs_idx], s_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-65cf801c1319> in <module>
#      20
#      21
# ---> 22 ns_unenc_c_overheads_7_91 = compute_overheads(NS_Unenc_C_Default_7_91, [NS_Unenc_C_Default_SendPlus_7_91, NS_Unenc_C_RingNB_7_91, NS_Unenc_C_ML_7_91, NS_Unenc_C_MLRD_7_91])
#      23
#      24
#
# NameError: name 'NS_Unenc_C_Default_7_91' is not defined

# %% [markdown]
# # NS - 8 Nodes, 128 ranks - Blocked

# %%
NS_Unenc_Default_8_128 = list(ns_data['Unnamed: 1'][59:81])
NS_Unenc_Default_SendPlus_8_128 = list(ns_data['Unnamed: 2'][59:81])
NS_Unenc_NB_8_128 = list(ns_data['Unnamed: 3'][59:81])
NS_Unenc_RingNB_8_128 = list(ns_data['Unnamed: 4'][59:81])
NS_Unenc_ML_8_128 = list(ns_data['Unnamed: 5'][59:81])
NS_Unenc_MLRD_8_128 = list(ns_data['Unnamed: 6'][59:81])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_Unenc_Default_8_128[:6], NS_Unenc_Default_SendPlus_8_128[:6], NS_Unenc_RingNB_8_128[:6], NS_Unenc_ML_8_128[:6], NS_Unenc_MLRD_8_128[:6]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_Unenc_Default_8_128[6:], NS_Unenc_Default_SendPlus_8_128[6:], NS_Unenc_RingNB_8_128[6:], NS_Unenc_ML_8_128[6:], NS_Unenc_MLRD_8_128[6:]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()



ns_unenc_overheads_8_128 = compute_overheads(NS_Unenc_Default_8_128, [NS_Unenc_Default_SendPlus_8_128, NS_Unenc_RingNB_8_128, NS_Unenc_ML_8_128, NS_Unenc_MLRD_8_128])


first_large_msgs_idx = 6
s_m_overheads, l_m_overheads = categorize(ns_unenc_overheads_8_128, first_large_msgs_idx)


plot_overheads(MessageSizes[:first_large_msgs_idx], s_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plot_overheads(MessageSizes[first_large_msgs_idx:], l_m_overheads, ['Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

# %% [markdown]
# # NS - 8 Nodes, 128 ranks - Cyclic

# %%
NS_Unenc_C_Default_8_128 = list(ns_data['Unnamed: 1'][87:109])
NS_Unenc_C_Default_SendPlus_8_128 = list(ns_data['Unnamed: 2'][87:109])
NS_Unenc_C_NB_8_128 = list(ns_data['Unnamed: 3'][87:109])
NS_Unenc_C_RingNB_8_128 = list(ns_data['Unnamed: 4'][87:109])
NS_Unenc_C_ML_8_128 = list(ns_data['Unnamed: 5'][87:109])
NS_Unenc_C_MLRD_8_128 = list(ns_data['Unnamed: 6'][87:109])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)

my_plot(h1, MessageSizes[:6], [NS_Unenc_C_Default_8_128[:6], NS_Unenc_C_Default_SendPlus_8_128[:6], NS_Unenc_C_RingNB_8_128[:6], NS_Unenc_C_ML_8_128[:6], NS_Unenc_C_MLRD_8_128[:6]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])
my_plot(h2, MessageSizes[6:], [NS_Unenc_C_Default_8_128[6:], NS_Unenc_C_Default_SendPlus_8_128[6:], NS_Unenc_C_RingNB_8_128[6:], NS_Unenc_C_ML_8_128[6:], NS_Unenc_C_MLRD_8_128[6:]], ['Default', 'Default+', 'RingNB', 'ML-Ring', 'ML-RD'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()

# %% [markdown]
# # GNU Plot

# %%
import PyGnuplot as gp
from math import log



def SmallGnuPlot(x, data, label, captions):
    
    for i in range(len(data)):
        gp.s([x, data[i]], captions[i])

    cmd = '''gnuplot -e "label='{}'" Plot_Small.p'''.format(label)
    os.system(cmd)
    
def LargeGnuPlot(x, data, label, captions):
    
    for i in range(len(data)):
        gp.s([x, data[i]], captions[i])

    cmd = '''gnuplot -e "label='{}'" Plot_Large.p'''.format(label)
    os.system(cmd)

# %%
SmallGnuPlot(MessageSizes[:6], [NS_Unenc_C_Default_8_128[:6], NS_Unenc_Default_8_128[:6], NS_Unenc_NB_8_128[:6], NS_Unenc_RingNB_8_128[:6]], 'unenc-ns-small-existing', ['Default-Block', 'Default-Cyclic', 'NB', 'RingNB'])

LargeGnuPlot(MessageSizes[6:], [NS_Unenc_C_Default_8_128[6:], NS_Unenc_Default_8_128[6:], NS_Unenc_NB_8_128[6:], NS_Unenc_RingNB_8_128[6:]], 'unenc-ns-large-existing', ['Default-Block', 'Default-Cyclic', 'NB', 'RingNB'])

# %% [markdown]
# # Bar Plots

# %%
def export_data(data, subsets, MessageSizes):
    bars = len(data)
    #bar_width = 1.0 / float(bars+1)
    index = 0
    offsets = [1, 1, 1000, 1000]
    for i in range(len(subsets)):
#        line = 0
        with open('bar_data_'+str(i)+'.dat', 'w') as output:
            for k in range(subsets[i]):
                new_line = str(MessageSizes[index])
                for j in range(bars):
                    new_line +=  " " + str(data[j][index])
#                     line+=1
                    if j == bars-1:
                        index+=1
                        output.write(new_line)
                        output.write("\n")
#                         line+=1

def bar_plot(idx, subsets, label):
    types = ['Small', 'Med', 'Large', 'Large']
    cmd = '''gnuplot -e "label='{}'" -e "file='{}'" Bar_Plot_{}.p'''.format(label+str(idx), 'bar_data_'+str(idx)+'.dat', types[idx])
    os.system(cmd)

# %%
subsets = [6, 6, 5, 5]
data = [NS_Unenc_Default_8_128, NS_Unenc_C_Default_8_128, NS_Unenc_NB_8_128, NS_Unenc_RingNB_8_128]

#export_data(data, subsets, MessageSizes)
start = 0
for i in range(len(subsets)):
    msgs = MessageSizes[start:start + subsets[i]]
    start += subsets[i]
    bar_plot(i, subsets, 'unenc_NS_defaults_')

# %%
# Out:
# [256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152]
