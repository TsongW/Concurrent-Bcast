# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math
import PyGnuplot as gp

sns.set()
sns.set_style("whitegrid")



data = pd.read_excel('Allgather-MVAPICH-Innovation.xlsx', sheet_name='Summary')

MessageSizes = list(data['Unnamed: 0'][4:24])

# %%
import matplotlib.font_manager as font_manager
font_prop = font_manager.FontProperties(size=20, family='Times')
def my_plot(subplot, x, y, labels):    
    colors = ['blue', 'red', 'green', 'black', 'orange', 'teal', 'purple', 'navy']
    
    for i in range(len(labels)):
        subplot.plot(x, y[i], '-x', color=colors[i], label=labels[i] , markersize=10, linewidth=2)
    
    
    subplot.tick_params(labelsize=14)
    subplot.set_xticks(x[-4:])
    
    
    subplot.set_xlabel('Message Size (B)', fontproperties=font_prop)
    subplot.set_ylabel('Latency (us)', fontproperties=font_prop)
    
    subplot.legend(fontsize=15)
    
def compute_overheads(base, results):
    overheads=[]
    for r in results:
        overheads.append([100*(i-j)/j for i,j in zip(r, base)])
    return overheads

def plot_overheads(x, overheads, labels):
    colors = ['orange', 'red', 'green', 'blue', 'black']
    barwidth = 0.15
    fig =plt.subplots(figsize=(20, 8))
    
    for i in range(len(overheads)):
        x_br = [j + i*barwidth for j in range(len(x))]
        plt.bar(x_br, overheads[i], width=barwidth, label=labels[i], color=colors[i])
        
    plt.xlabel('Message Size (B)')
    plt.ylabel('Latency Overhead %')
    
    plt.xticks([r + barwidth for r in range(len(MessageSizes))], [str(s) for s in MessageSizes])
    plt.legend(fontsize=15)
    plt.show()

# %% [markdown]
# # 4 Nodes - 32 ranks

# %% [markdown]
# ## Unencrypted

# %%
Unenc_Default_4_32 = list(data['Unnamed: 1'][89:109])
Unenc_Default_SendPlus_4_32 = list(data['Unnamed: 2'][89:109])
Unenc_NB_4_32 = list(data['Unnamed: 3'][89:109])
Unenc_RingNB_4_32 = list(data['Unnamed: 4'][89:109])
Unenc_ML_4_32 = list(data['Unnamed: 5'][89:109])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4_32[:13], Unenc_Default_SendPlus_4_32[:13], Unenc_NB_4_32[:13], Unenc_RingNB_4_32[:13], Unenc_ML_4_32[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4_32[13:], Unenc_Default_SendPlus_4_32[13:], Unenc_NB_4_32[13:], Unenc_RingNB_4_32[13:], Unenc_ML_4_32[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()

# %%
overheads_4_32 = compute_overheads(Unenc_Default_4_32, [Unenc_Default_SendPlus_4_32, Unenc_NB_4_32, Unenc_RingNB_4_32, Unenc_ML_4_32])

s_m_overheads, m_m_overheads, l_m_overheads = categorize(overheads, 9, 13)


plot_overheads(MessageSizes[:9], overheads_4_32, ['Send+', 'NB', 'RingNB', 'MultiLeader'])

# %% [markdown]
# ## Naive

# %%
Naive_Default_4_32 = list(data['Unnamed: 6'][89:109])
Naive_Default_SendPlus_4_32 = list(data['Unnamed: 7'][89:109])
Naive_NB_4_32 = list(data['Unnamed: 8'][89:109])
Naive_RingNB_4_32 = list(data['Unnamed: 9'][89:109])
Naive_ML_4_32 = list(data['Unnamed: 10'][89:109])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Naive_Default_4_32[:13], Naive_Default_SendPlus_4_32[:13], Naive_NB_4_32[:13], Naive_RingNB_4_32[:13], Naive_ML_4_32[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])
my_plot(h2, MessageSizes[13:], [Naive_Default_4_32[13:], Naive_Default_SendPlus_4_32[13:], Naive_NB_4_32[13:], Naive_RingNB_4_32[13:], Naive_ML_4_32[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive", fontproperties=font_prop)

plt.show()

# %%
overheads_Naiuve_4_32 = compute_overheads(Unenc_Default_4_32, [Naive_Default_4_32, Naive_Default_SendPlus_4_32, Naive_NB_4_32, Naive_RingNB_4_32, Naive_ML_4_32])
plot_overheads(MessageSizes, overheads_Naiuve_4_32, ['Default', 'Send+', 'NB', 'RingNB', 'MultiLeader'])

# %% [markdown]
# ## Naive+

# %%
NaivePlus_Default_4_32 = list(data['Unnamed: 11'][89:109])
NaivePlus_Default_SendPlus_4_32 = list(data['Unnamed: 12'][89:109])
NaivePlus_NB_4_32 = list(data['Unnamed: 13'][89:109])
NaivePlus_RingNB_4_32 = list(data['Unnamed: 14'][89:109])
NaivePlus_ML_4_32 = list(data['Unnamed: 15'][89:109])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [NaivePlus_Default_4_32[:13], NaivePlus_Default_SendPlus_4_32[:13], NaivePlus_NB_4_32[:13], NaivePlus_RingNB_4_32[:13], NaivePlus_ML_4_32[:13]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])
my_plot(h2, MessageSizes[13:], [NaivePlus_Default_4_32[13:], NaivePlus_Default_SendPlus_4_32[13:], NaivePlus_NB_4_32[13:], NaivePlus_RingNB_4_32[13:], NaivePlus_ML_4_32[13:]], ['Default', 'Default Send+', 'NB', 'RingNB', 'MultiLeader'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive +", fontproperties=font_prop)

plt.show()

# %%
overheads_NaivePlus_4_32 = compute_overheads(Unenc_Default_4_32, [NaivePlus_Default_4_32, NaivePlus_Default_SendPlus_4_32, NaivePlus_NB_4_32, NaivePlus_RingNB_4_32, NaivePlus_ML_4_32])
plot_overheads(MessageSizes, overheads_NaivePlus_4_32, ['Default', 'Send+', 'NB', 'RingNB', 'MultiLeader'])

# %% [markdown]
# # 4 Nodes - 64 ranks

# %% [markdown]
# ## Unencrupted

# %%
Unenc_Default_4 = list(data['Unnamed: 1'][145:165])
Unenc_Default_SendPlus_4 = list(data['Unnamed: 2'][145:165])
Unenc_ML_4 = list(data['Unnamed: 5'][145:165])
Unenc_RingNB_4 = list(data['Unnamed: 4'][145:165])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4[:13], Unenc_Default_SendPlus_4[:13], Unenc_ML_4[:13], Unenc_RingNB_4[:13]], ['Default', 'Default Send+', 'MultiLeader', 'RingNB'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4[13:], Unenc_Default_SendPlus_4[13:], Unenc_ML_4[13:], Unenc_RingNB_4[13:]], ['Default', 'Default Send+', 'MultiLeader', 'RingNB'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()

# %% [markdown]
# ## Naive

# %%
Naive_Default_4 = list(data['Unnamed: 6'][145:165])
Naive_Default_SendPlus_4 = list(data['Unnamed: 7'][145:165])
Naive_ML_4 = list(data['Unnamed: 10'][145:165])
Naive_RingNB_4 = list(data['Unnamed: 9'][145:165])


f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Naive_Default_4[:13], Naive_Default_SendPlus_4[:13], Naive_ML_4[:13], Naive_RingNB_4[:13]], ['Default', 'Default Send+', 'MultiLeader', 'RingNB'])
my_plot(h2, MessageSizes[13:], [Naive_Default_4[13:], Naive_Default_SendPlus_4[13:], Naive_ML_4[13:], Naive_RingNB_4[13:]], ['Default', 'Default Send+', 'MultiLeader', 'RingNB'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive", fontproperties=font_prop)
plt.show()

# %% [markdown]
# ## Naive+

# %%
NaivePlus_Default_4 = list(data['Unnamed: 11'][145:165])
NaivePlus_Default_SendPLus_4 = list(data['Unnamed: 12'][145:165])
NaivePlus_ML_4 = list(data['Unnamed: 15'][145:165])
NaivePlus_RingNB_4 = list(data['Unnamed: 14'][145:165])


f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [NaivePlus_Default_4[:13], NaivePlus_Default_SendPLus_4[:13], NaivePlus_ML_4[:13], NaivePlus_RingNB_4[:13]], ['Default', 'Default Send+', 'MultiLeader', 'RingNB'])
my_plot(h2, MessageSizes[13:], [NaivePlus_Default_4[13:], NaivePlus_Default_SendPLus_4[13:], NaivePlus_ML_4[13:], NaivePlus_RingNB_4[13:]], ['Default', 'Default Send+', 'MultiLeader', 'RingNB'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive+", fontproperties=font_prop)
plt.show()

# %% [markdown]
# # Default

# %%
f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4[:13], Naive_Default_4[:13], NaivePlus_Default_4[:13]], ['Unencrypted', 'Naive', 'Naive+'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4[13:], Naive_Default_4[13:], NaivePlus_Default_4[13:]], ['Unencrypted', 'Naive', 'Naive+'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Default algorithm", fontproperties=font_prop)
plt.show()

# %% [markdown]
# # RingNB

# %%
f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_RingNB_4[:13], Naive_RingNB_4[:13], NaivePlus_RingNB_4[:13]], ['Unencrypted', 'Naive', 'Naive+'])
my_plot(h2, MessageSizes[13:], [Unenc_RingNB_4[13:], Naive_RingNB_4[13:], NaivePlus_RingNB_4[13:]], ['Unencrypted', 'Naive', 'Naive+'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("RingNB Algorithm", fontproperties=font_prop)
plt.show()

# %% [markdown]
# # ML

# %%
f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_ML_4[:13], Naive_ML_4[:13], NaivePlus_ML_4[:13]], ['Unencrypted', 'Naive', 'Naive+'])
my_plot(h2, MessageSizes[13:], [Unenc_ML_4[13:], Naive_ML_4[13:], NaivePlus_ML_4[13:]], ['Unencrypted', 'Naive', 'Naive+'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("MultiLeader Algorithm", fontproperties=font_prop)
plt.show()

# %% [markdown]
# # Comparing Naive+ with Unencrypted Default

# %%
f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4[:13], NaivePlus_Default_4[:13], NaivePlus_ML_4[:13], NaivePlus_RingNB_4[:13]], ['Unencrypted Default', 'Naive+ Default', 'Naive+ ML', 'Naive+ RingNB'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4[13:], NaivePlus_Default_4[13:], NaivePlus_ML_4[13:], NaivePlus_RingNB_4[13:]], ['Unencrypted Default', 'Naive+ Default', 'Naive+ ML', 'Naive+ RingNB'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Comparing Naive+ with Unencrypted Default", fontproperties=font_prop)
plt.show()

# %% [markdown]
# # Comparing Block and Cyclic rank alignments

# %% [markdown]
# # Default

# %%
Unenc_Default_Cyclic = list(data['Unnamed: 1'][173:193])
Unenc_Default_SendPlus_Cyclic = list(data['Unnamed: 2'][173:193])
Unenc_NB_Cyclic = list(data['Unnamed: 3'][173:193])
Unenc_RingNB_Cyclic = list(data['Unnamed: 4'][173:193])



f = plt.figure(figsize=(16,18))
h1 = f.add_subplot(421)
h2 = f.add_subplot(422)
h3 = f.add_subplot(423)
h4 = f.add_subplot(424)
h5 = f.add_subplot(425)
h6 = f.add_subplot(426)
h7 = f.add_subplot(427)
h8 = f.add_subplot(428)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4[:13], Unenc_Default_Cyclic[:13]], ['Default-Block', 'Default-Cyclic'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4[13:], Unenc_Default_Cyclic[13:]], ['Default-Block', 'Default-Cyclic'])

# my_plot(h3, MessageSizes[:13], [Unenc_Default_SendPlus_4[:13], Unenc_Default_SendPlus_Cyclic[:13]], ['Default Send+ Block', 'Default Send+ Cyclic'])
# my_plot(h4, MessageSizes[13:], [Unenc_Default_SendPlus_4[13:], Unenc_Default_SendPlus_Cyclic[13:]], ['Default Send+ Block', 'Default Send+ Cyclic'])


# my_plot(h5, MessageSizes[:13], [Unenc_NB_4[:13], Unenc_NB_Cyclic[:13]], ['NB-Block', 'NB-Cyclic'])
# my_plot(h6, MessageSizes[13:], [Unenc_NB_4[13:], Unenc_NB_Cyclic[13:]], ['NB-Block', 'NB-Cyclic'])


my_plot(h3, MessageSizes[:13], [Unenc_RingNB_4[:13], Unenc_RingNB_Cyclic[:13]], ['RingNB-Block', 'RingNB-Cyclic'])
my_plot(h4, MessageSizes[13:], [Unenc_RingNB_4[13:], Unenc_RingNB_Cyclic[13:]], ['RingNB-Block', 'RingNB-Cyclic'])


# plt.legend(prop=font_prop)
plt.tight_layout()
plt.show()
