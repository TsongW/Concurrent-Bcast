# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math
import PyGnuplot as gp

sns.set()
sns.set_style("whitegrid")



data = pd.read_excel('Results.xlsx', sheet_name='Summary')

MessageSizes = list(data['Unnamed: 0'][4:24])

# %%
import matplotlib.font_manager as font_manager
font_prop = font_manager.FontProperties(size=20, family='Times')
def my_plot(subplot, x, y, labels):    
    colors = ['blue', 'red', 'green', 'black', 'orange', 'teal', 'purple', 'navy']
    
    for i in range(len(labels)):
        subplot.plot(x, y[i], '-x', color=colors[i], label=labels[i] , markersize=10, linewidth=2)
    
    
    subplot.tick_params(labelsize=14)
    subplot.set_xticks(x[-4:])
    
    
    subplot.set_xlabel('Message Size (B)', fontproperties=font_prop)
    subplot.set_ylabel('Latency (us)', fontproperties=font_prop)
    
    subplot.legend(fontsize=15)

# %% [markdown]
# # 2 Nodes

# %% [markdown]
# ## Unecnrypted

# %%
Unenc_Default_2 = list(data['Unnamed: 1'][4:24])
Unenc_Default_SendPlus_2 = list(data['Unnamed: 2'][4:24])
Unenc_NB_2 = list(data['Unnamed: 3'][4:24])
Unenc_RingNB_2 = list(data['Unnamed: 4'][4:24])

f = plt.figure(figsize=(16,6))

h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_2[:13], Unenc_Default_SendPlus_2[:13], Unenc_NB_2[:13], Unenc_RingNB_2[:13]], ['Default', 'Default Send+', 'NB', 'RingNB'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_2[13:], Unenc_Default_SendPlus_2[13:], Unenc_NB_2[13:], Unenc_RingNB_2[13:]], ['Default', 'Default Send+', 'NB', 'RingNB'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("aaa")
plt.show()

# %% [markdown]
# ## Naive

# %%
Naive_Default_2 = list(data['Unnamed: 5'][4:24])
Naive_Default_SendPlus_2 = list(data['Unnamed: 6'][4:24])
Naive_NB_2 = list(data['Unnamed: 7'][4:24])
Naive_RingNB_2 = list(data['Unnamed: 8'][4:24])


f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Naive_Default_2[:13], Naive_Default_SendPlus_2[:13], Naive_NB_2[:13], Naive_RingNB_2[:13]], ['Default', 'Default Send+' 'NB', 'RingNB'])
my_plot(h2, MessageSizes[13:], [Naive_Default_2[13:], Naive_Default_SendPlus_2[13:], Naive_NB_2[13:], Naive_RingNB_2[13:]], ['Default', 'Default Send+', 'NB', 'RingNB'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Naive+

# %%
NaivePlus_Default_2 = list(data['Unnamed: 9'][4:24])
NaivePlus_Default_SendPlus_2 = list(data['Unnamed: 10'][4:24])
NaivePlus_NB_2 = list(data['Unnamed: 11'][4:24])
NaivePlus_RingNB_2 = list(data['Unnamed: 12'][4:24])


f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [NaivePlus_Default_2[:13], NaivePlus_Default_SendPlus_2[:13], NaivePlus_NB_2[:13], NaivePlus_RingNB_2[:13]], ['Default', 'Default Send+', 'NB', 'RingNB'])
my_plot(h2, MessageSizes[13:], [NaivePlus_Default_2[13:], NaivePlus_Default_SendPlus_2[13:], NaivePlus_NB_2[13:], NaivePlus_RingNB_2[13:]], ['Default', 'Default Send+', 'NB', 'RingNB'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Default

# %%
f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_2[:13], Unenc_Default_SendPlus_2[:13],  Naive_Default_2[:13], NaivePlus_Default_2[:13]], ['Unencrypted', 'Unencrypted Send+', 'Naive', 'Naive+'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_2[13:], Unenc_Default_SendPlus_2[13:], Naive_Default_2[13:], NaivePlus_Default_2[13:]], ['Unencrypted', 'Unencrypted Send+', 'Naive', 'Naive+'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## RingNB

# %%
f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_RingNB_2[:13], Naive_RingNB_2[:13], NaivePlus_RingNB_2[:13]], ['Unencrypted', 'Naive', 'Naive+'])
my_plot(h2, MessageSizes[13:], [Unenc_RingNB_2[13:], Naive_RingNB_2[13:], NaivePlus_RingNB_2[13:]], ['Unencrypted', 'Naive', 'Naive+'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## NB

# %%
f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_NB_2[:13], Naive_NB_2[:13], NaivePlus_NB_2[:13]], ['Unencrypted', 'Naive', 'Naive+'])
my_plot(h2, MessageSizes[13:], [Unenc_NB_2[13:], Naive_NB_2[13:], NaivePlus_NB_2[13:]], ['Unencrypted', 'Naive', 'Naive+'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparison with Unencrypted Default

# %%
f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_2[:13], Unenc_Default_SendPlus_2[:13], NaivePlus_Default_2[:13], NaivePlus_NB_2[:13], NaivePlus_RingNB_2[:13]], ['Unencrypted Default', 'Unencrypted Send+', 'Naive+ Default', 'Naive+ NB', 'Naive+ RingNB'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_2[13:], Unenc_Default_SendPlus_2[13:], NaivePlus_Default_2[13:], NaivePlus_NB_2[13:], NaivePlus_RingNB_2[13:]], ['Unencrypted Default', 'Unencrypted Send+', 'Naive+ Default', 'Naive+ NB', 'Naive+ RingNB'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4 Nodes - 64 ranks

# %% [markdown]
# ## Unencrupted

# %%
Unenc_Default_4 = list(data['Unnamed: 1'][145:165])
Unenc_Default_SendPlus_4 = list(data['Unnamed: 2'][145:165])
Unenc_NB_4 = list(data['Unnamed: 3'][145:165])
Unenc_RingNB_4 = list(data['Unnamed: 4'][145:165])

f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4[:13], Unenc_Default_SendPlus_4[:13], Unenc_NB_4[:13], Unenc_RingNB_4[:13]], ['Default', 'Default Send+', 'NB', 'RingNB'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4[13:], Unenc_Default_SendPlus_4[13:], Unenc_NB_4[13:], Unenc_RingNB_4[13:]], ['Default', 'Default Send+', 'NB', 'RingNB'])



plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Unencrypted", fontproperties=font_prop)

plt.show()

# %% [markdown]
# ## Naive

# %%
Naive_Default_4 = list(data['Unnamed: 5'][145:165])
Naive_Default_SendPlus_4 = list(data['Unnamed: 6'][145:165])
Naive_NB_4 = list(data['Unnamed: 7'][145:165])
Naive_RingNB_4 = list(data['Unnamed: 8'][145:165])


f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Naive_Default_4[:13], Naive_Default_SendPlus_4[:13], Naive_NB_4[:13], Naive_RingNB_4[:13]], ['Default', 'Default Send+', 'NB', 'RingNB'])
my_plot(h2, MessageSizes[13:], [Naive_Default_4[13:], Naive_Default_SendPlus_4[13:], Naive_NB_4[13:], Naive_RingNB_4[13:]], ['Default', 'Default Send+', 'NB', 'RingNB'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive", fontproperties=font_prop)
plt.show()

# %% [markdown]
# ## Naive+

# %%
NaivePlus_Default_4 = list(data['Unnamed: 9'][145:165])
NaivePlus_Default_SendPLus_4 = list(data['Unnamed: 10'][145:165])
NaivePlus_NB_4 = list(data['Unnamed: 11'][145:165])
NaivePlus_RingNB_4 = list(data['Unnamed: 12'][145:165])


f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [NaivePlus_Default_4[:13], NaivePlus_Default_SendPLus_4[:13], NaivePlus_NB_4[:13], NaivePlus_RingNB_4[:13]], ['Default', 'Default Send+', 'NB', 'RingNB'])
my_plot(h2, MessageSizes[13:], [NaivePlus_Default_4[13:], NaivePlus_Default_SendPLus_4[13:], NaivePlus_NB_4[13:], NaivePlus_RingNB_4[13:]], ['Default', 'Default Send+', 'NB', 'RingNB'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Naive+", fontproperties=font_prop)
plt.show()

# %% [markdown]
# # Default

# %%
f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4[:13], Naive_Default_4[:13], NaivePlus_Default_4[:13]], ['Unencrypted', 'Naive', 'Naive+'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4[13:], Naive_Default_4[13:], NaivePlus_Default_4[13:]], ['Unencrypted', 'Naive', 'Naive+'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Default algorithm", fontproperties=font_prop)
plt.show()

# %% [markdown]
# # RingNB

# %%
f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_RingNB_4[:13], Naive_RingNB_4[:13], NaivePlus_RingNB_4[:13]], ['Unencrypted', 'Naive', 'Naive+'])
my_plot(h2, MessageSizes[13:], [Unenc_RingNB_4[13:], Naive_RingNB_4[13:], NaivePlus_RingNB_4[13:]], ['Unencrypted', 'Naive', 'Naive+'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("RingNB Algorithm", fontproperties=font_prop)
plt.show()

# %% [markdown]
# # NB

# %%
f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_NB_4[:13], Naive_NB_4[:13], NaivePlus_NB_4[:13]], ['Unencrypted', 'Naive', 'Naive+'])
my_plot(h2, MessageSizes[13:], [Unenc_NB_4[13:], Naive_NB_4[13:], NaivePlus_NB_4[13:]], ['Unencrypted', 'Naive', 'Naive+'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("NB Algorithm", fontproperties=font_prop)
plt.show()

# %% [markdown]
# # Comparing Naive+ with Unencrypted Default

# %%
f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4[:13], NaivePlus_Default_4[:13], NaivePlus_NB_4[:13], NaivePlus_RingNB_4[:13]], ['Unencrypted Default', 'Naive+ Default', 'Naive+ NB', 'Naive+ RingNB'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4[13:], NaivePlus_Default_4[13:], NaivePlus_NB_4[13:], NaivePlus_RingNB_4[13:]], ['Unencrypted Default', 'Naive+ Default', 'Naive+ NB', 'Naive+ RingNB'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.title("Comparing Naive+ with Unencrypted Default", fontproperties=font_prop)
plt.show()

# %% [markdown]
# # 4-20

# %%
Unenc_Default_4_20 = list(data['Unnamed: 1'][61:81])
NaivePlus_Default_SendPLus_4_20 = list(data['Unnamed: 10'][61:81])
NaivePlus_Default_4_20 = list(data['Unnamed: 9'][61:81])
NaivePlus_NB_4_20 = list(data['Unnamed: 11'][61:81])
NaivePlus_RingNB_4_20 = list(data['Unnamed: 12'][61:81])



f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4_20[:13], NaivePlus_Default_SendPLus_4_20[:13], NaivePlus_Default_4_20[:13], NaivePlus_NB_4_20[:13], NaivePlus_RingNB_4_20[:13]], ['Unencrypted Default', 'Default Send+', 'Naive+ Default', 'Naive+ NB', 'Naive+ RingNB'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4_20[13:], NaivePlus_Default_SendPLus_4_20[13:], NaivePlus_Default_4_20[13:], NaivePlus_NB_4_20[13:], NaivePlus_RingNB_4_20[13:]], ['Unencrypted Default', 'Default Send+', 'Naive+ Default', 'Naive+ NB', 'Naive+ RingNB'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.show()
# Out:
# [38.92, 54.2, 53.87, 36.59, 37.01, 53.96, 57.53, 63.1, 73.97, 108.78, 165.34, 286.26, 507.69, 344.7, 575.15, 986.06, 1908.77, 4218.55, 8038.14, 15835.07]

# %% [markdown]
# ## 4-32

# %%
Unenc_Default_4_32 = list(data['Unnamed: 1'][89:109])

NaivePlus_Default_4_32 = list(data['Unnamed: 7'][89:109])
NaivePlus_NB_4_32 = list(data['Unnamed: 8'][89:109])
NaivePlus_RingNB_4_32 = list(data['Unnamed: 9'][89:109])



f = plt.figure(figsize=(16,6))
h1 = f.add_subplot(121)
h2 = f.add_subplot(122)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4_32[:13], NaivePlus_Default_4_32[:13], NaivePlus_NB_4_32[:13], NaivePlus_RingNB_4_32[:13]], ['Unencrypted Default', 'Naive+ Default', 'Naive+ NB', 'Naive+ RingNB'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4_32[13:], NaivePlus_Default_4_32[13:], NaivePlus_NB_4_32[13:], NaivePlus_RingNB_4_32[13:]], ['Unencrypted Default', 'Naive+ Default', 'Naive+ NB', 'Naive+ RingNB'])

plt.legend(prop=font_prop)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparing Block and Cyclic rank alignments

# %% [markdown]
# # Default

# %%
Unenc_Default_Cyclic = list(data['Unnamed: 1'][173:193])
Unenc_Default_SendPlus_Cyclic = list(data['Unnamed: 2'][173:193])
Unenc_NB_Cyclic = list(data['Unnamed: 3'][173:193])
Unenc_RingNB_Cyclic = list(data['Unnamed: 4'][173:193])



f = plt.figure(figsize=(16,18))
h1 = f.add_subplot(421)
h2 = f.add_subplot(422)
h3 = f.add_subplot(423)
h4 = f.add_subplot(424)
h5 = f.add_subplot(425)
h6 = f.add_subplot(426)
h7 = f.add_subplot(427)
h8 = f.add_subplot(428)


my_plot(h1, MessageSizes[:13], [Unenc_Default_4[:13], Unenc_Default_Cyclic[:13]], ['Default-Block', 'Default-Cyclic'])
my_plot(h2, MessageSizes[13:], [Unenc_Default_4[13:], Unenc_Default_Cyclic[13:]], ['Default-Block', 'Default-Cyclic'])

# my_plot(h3, MessageSizes[:13], [Unenc_Default_SendPlus_4[:13], Unenc_Default_SendPlus_Cyclic[:13]], ['Default Send+ Block', 'Default Send+ Cyclic'])
# my_plot(h4, MessageSizes[13:], [Unenc_Default_SendPlus_4[13:], Unenc_Default_SendPlus_Cyclic[13:]], ['Default Send+ Block', 'Default Send+ Cyclic'])


# my_plot(h5, MessageSizes[:13], [Unenc_NB_4[:13], Unenc_NB_Cyclic[:13]], ['NB-Block', 'NB-Cyclic'])
# my_plot(h6, MessageSizes[13:], [Unenc_NB_4[13:], Unenc_NB_Cyclic[13:]], ['NB-Block', 'NB-Cyclic'])


my_plot(h3, MessageSizes[:13], [Unenc_RingNB_4[:13], Unenc_RingNB_Cyclic[:13]], ['RingNB-Block', 'RingNB-Cyclic'])
my_plot(h4, MessageSizes[13:], [Unenc_RingNB_4[13:], Unenc_RingNB_Cyclic[13:]], ['RingNB-Block', 'RingNB-Cyclic'])


# plt.legend(prop=font_prop)
plt.tight_layout()
plt.show()
